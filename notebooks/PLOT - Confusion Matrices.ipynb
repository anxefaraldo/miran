# %%
# %matplotlib inline
from miran import *

import matplotlib as mpl
import seaborn as sns

PRINT_QUALITY = 300

sns.set_style('white', {'axes.linewidth': 0.2,  'axes.edgecolor': 'gray'})#, 'axes.facecolor':'snow'})
sns.set_palette("Reds_d", 5); my_palette='Greys'; libcolor='Greys'
mpl.rc('font', **{'family':'serif', 'serif':['Times']})
mpl.rc('xtick', labelsize=8)
mpl.rc('ytick', labelsize=8)
mpl.rc('axes', labelsize=9)
mpl.rc('text', usetex=True)

# %%
plot_confusion_mtx('/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-LAX.xlsx', cmap=my_palette, save=False)

# %%
plot_relative_mtx('/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-LAX.xlsx', label='EDM-LAX', cmap=my_palette, save=True)

# %%
plot_relative_mtx('/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-POP.xlsx', label='POP', cmap=my_palette, save=False)
