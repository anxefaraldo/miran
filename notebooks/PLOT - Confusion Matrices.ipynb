# %%
# %matplotlib inline
from miran import *

import matplotlib as mpl
import seaborn as sns

PRINT_QUALITY = 300

sns.set_style('white', {'axes.linewidth': 0,  'axes.edgecolor': 'gray'})#, 'axes.facecolor':'snow'})
my_palette='Greys'; libcolor='Greys'
mpl.rc('font', **{'family':'serif', 'serif':['Times']})
mpl.rc('xtick', labelsize=8)
mpl.rc('ytick', labelsize=8)
mpl.rc('axes', labelsize=9)
mpl.rc('text', usetex=True)

# %%
plot_confusion_mtx('/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-LAX.xlsx', cmap=my_palette, save=False)

# %%
plot_relative_mtx('/Users/angel/Desktop/EDM-BGATE+.xlsx', label='EDM-LAX', cmap=my_palette, save=True)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-99cd1dc72865> in <module>()
# ----> 1 plot_relative_mtx('/Users/angel/Desktop/EDM-BGATE+.xlsx', label='EDM-LAX', cmap=my_palette, save=True)
#
# /usr/local/lib/python2.7/site-packages/miran-0.1-py2.7.egg/miran/plots.pyc in plot_relative_mtx(xlx_with_valid_matrix, label, output_dir, cmap, save)
#     229 def plot_relative_mtx(xlx_with_valid_matrix, label='', output_dir="/Users/angel/Dropbox/Apps/Texpad/Thesis/figures", cmap='Reds', save=False):
#     230
# --> 231     a = pd.read_excel(xlx_with_valid_matrix, sheetname=1)
#     232     aa = a.as_matrix()
#     233
#
# ...

# %%
plot_relative_mtx('/Users/angel/Desktop/POP-BGATE+.xlsx', label='POP', cmap=my_palette, save=True)
