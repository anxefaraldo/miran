# %%
# %matplotlib inline
from miran import *
import seaborn as sns
import matplotlib as mpl

PRINT_QUALITY = 300

sns.set_style('whitegrid', {'axes.linewidth': 0,  'axes.edgecolor': 'gray'})#, 'axes.facecolor':'snow'})
N_COLORS = 4
pa = sns.set_palette("Greys", N_COLORS)
mpl.rc('font', **{'family':'serif', 'serif':['Times']})
mpl.rc('xtick', labelsize=8)
mpl.rc('ytick', labelsize=8)
mpl.rc('axes', labelsize=9)
mpl.rc('text', usetex=True)

# %%
# CH6 EVAL 1

plt.figure(figsize=(5.16, 2.4), dpi=150)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-BASEDEF-TEMPERLEY.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-BASEMOD-TEMPERLEY.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-BASEDEF-SHAATH.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-BASEMOD-SHAATH.xlsx'])
cor, nei, rel, par, wei = a

plt.subplot(1,2,1)
plt.title("pop", y= 1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), ('default', 'modified', 'default', 'modified'))
plt.text(0, -0.21, 'temperley', fontsize=10)
plt.text(2.,-0.21,  'shaath', fontsize=10)
plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)
plt.text(-0.4, 1.40,  '0.65', fontsize=10)    
plt.text(0.16, 1.40,  'weighted', fontsize=8)
plt.legend(fontsize=8, frameon=False, loc=(0.45, 1.35), ncol=4)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-BASEDEF-TEMPERLEY.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-BASEMOD-TEMPERLEY.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-BASEDEF-SHAATH.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-BASEMOD-SHAATH.xlsx'])

cor, nei, rel, par, wei = a
plt.subplot(1,2,2)
plt.title(r"\textsc{edm} (\textsc{bp} + \textsc{gs}\textsuperscript{+})", y= 1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), ('default', 'modified', 'default', 'modified'))
plt.text(0.0, -0.21, 'temperley', fontsize=10)
plt.text(2.0,-0.21,  'shaath', fontsize=10)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .0))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/comparison_1.pdf', format="pdf", dpi=PRINT_QUALITY, bbox_inches='tight')

# %%
# CH6 EVAL 2

plt.figure(figsize=(5.16, 2.4), dpi=150)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-BASEDEF-EDMA.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-BASEMOD-EDMA.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-BASEDEF-EDMM.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-BASEMOD-EDMM.xlsx'])

plt.subplot(1,2,1)
cor, nei, rel, par, wei = a
plt.title('pop', y= 1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), ('default', 'modified', 'default', 'modified'))

plt.text(0.15, -0.21, r'\textsc{edma}', fontsize=10)
plt.text(2,-0.21,  r'\textsc{edmm}', fontsize=10)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.text(-0.4, 1.40,  '0.61', fontsize=10)    
plt.text(0.16, 1.40,  'weighted', fontsize=8)
plt.legend(fontsize=8, frameon=False, loc=(0.45, 1.35), ncol=4)


a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-BASEDEF-EDMA.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-BASEMOD-EDMA.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-BASEDEF-EDMM.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-BASEMOD-EDMM.xlsx'])

cor, nei, rel, par, wei = a

plt.subplot(1,2,2)
plt.title(r"\textsc{edm} (\textsc{bp} + \textsc{gs}\textsuperscript{+})", y= 1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), ('default', 'modified', 'default', 'modified'))
plt.text(0.15, -0.21, r'\textsc{edma}', fontsize=10)
plt.text(2,-0.21,  r'\textsc{edmm}', fontsize=10)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .0))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/comparison_2.pdf', format="pdf", dpi=PRINT_QUALITY, bbox_inches='tight')

# %%
# EVAL 3

plt.figure(figsize=(5.16, 4.4), dpi=150)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-BASEMOD-EDMA.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-SW-EDMA.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-DC-EDMA.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-FINAL-EDMA.xlsx'])
cor, nei, rel, par, wei = a
plt.subplot(2,2,1)
plt.title('pop', y= 1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), ('simple', 'sp. whit', 'det. det', 'combined'))
plt.text(-1.7, 0.6, r'\textsc{edma}', fontsize=11, rotation=90)
plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.text(-0.4, 1.40,  '0.61', fontsize=10)    
plt.text(0.16, 1.40,  'weighted', fontsize=8)
plt.legend(fontsize=8, frameon=False, loc=(0.45, 1.35), ncol=4)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-BASEMOD-EDMA.xlsx', 
                         '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-SW-EDMA.xlsx', 
                         '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-DC-EDMA.xlsx',
                         '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-FINAL-EDMA.xlsx'])

plt.subplot(2,2,2)
cor, nei, rel, par, wei = a
plt.title(r"\textsc{edm} (\textsc{bp} + \textsc{gs}\textsuperscript{+})", y= 1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), ('simple', 'sp. whit', 'det. det', 'combined'))
plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .0))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-BASEMOD-EDMM.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-SW-EDMM.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-DC-EDMM.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-POP-FINAL-EDMM.xlsx'])

plt.subplot(2,2,3)
cor, nei, rel, par, wei = a
plt.title('-', y= 1, color='white')
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.text(-1.7, 0.6, r'\textsc{edmm}', fontsize=11, rotation=90)
plt.xticks(range(len(a[0])), ('simple', 'sp. whit', 'det. det', 'combined'))
plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)
 
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-BASEMOD-EDMM.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-SW-EDMM.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-DC-EDMM.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-EDM-FINAL-EDMM.xlsx'])

plt.subplot(2,2,4)
cor, nei, rel, par, wei = a
plt.title('_', y= 1, color='white')
plt.ylim([0,1])
plt.xticks(range(len(a[0])), ('simple', 'sp. whit', 'det. det', 'combined'))
plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/comparison_3.png', format="png", dpi=PRINT_QUALITY, bbox_inches='tight', transparent=True)

# %%
# CHAPTER 6 EVAL 4

plt.figure(figsize=(5.16, 2.4), dpi=150)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-BTL-FINAL-EDMA-MIREX.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-BTL-FINAL-EDMM-MIREX.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-BTL-FINAL-EDMA-MIREX.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-BTL-FINAL-EDMM-MIREX.xlsx'])

plt.subplot(1,2,1)
cor, nei, rel, par, wei = a
plt.title(r'\textsc{btl}', y= 1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), (r'\textsc{edma}', r'\textsc{edmm}', r'\textsc{edma}', r'\textsc{edmm}'))
plt.text(0.2,-0.19,  r'\textsc{mirex}', fontsize=10)
plt.text(1.7,-0.19,  r'{lax-ambiguous}', fontsize=10)

#plt.text(1.15,-0.3,  '$ws(hs)$', fontsize=11)
plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.text(-0.4, 1.40,  '0.76', fontsize=10)    
plt.text(0.16, 1.40,  'weighted', fontsize=8)
plt.legend(fontsize=8, frameon=False, loc=(0.45, 1.35), ncol=4)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-GS-FINAL-EDMA-MIREX.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-GS-FINAL-EDMM-MIREX.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-GS-FINAL-EDMA-AMBI.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/ECIR-GS-FINAL-EDMM-AMBI.xlsx'])

cor, nei, rel, par, wei = a

plt.subplot(1,2,2)
plt.title(r'\textsc{gs\textsuperscript{+}}', y= 1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), (r'\textsc{edma}', r'\textsc{edmm}', r'\textsc{edma}', r'\textsc{edmm}'))
plt.text(0.2,-0.19,  r'\textsc{mirex}', fontsize=10)
plt.text(1.7,-0.19,  r'{lax-ambiguous}', fontsize=10)
plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .0))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/comparison_4.pdf', format="pdf", dpi=PRINT_QUALITY, bbox_inches='tight')

# %%
# CHPATER 6 EVAL 5

plt.figure(figsize=(5.16, 2.4), dpi=150)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-BASELINE.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-100.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-200.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-250.xlsx'])
cor, nei, rel, par, wei = a

plt.subplot(1,2,1)
plt.title("pop", y= 1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), ('baseline', 'hpf@100', 'hpf@200', 'hpf@250'))

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)
    
plt.text(-0.4, 1.40,  '0.80', fontsize=10)    
plt.text(0.16, 1.40,  'weighted', fontsize=8)
plt.legend(fontsize=8, frameon=False, loc=(0.45, 1.35), ncol=4)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-BASELINE.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-100.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-200.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-250.xlsx'])

cor, nei, rel, par, wei = a
plt.subplot(1,2,2)
plt.title(r"\textsc{edm} (\textsc{kfd} + \textsc{gs\textsuperscript{+}})", y= 1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), ('baseline', 'hpf@100', 'hpf@200', 'hpf@250'))

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .0))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/comparison_1b.pdf', format="pdf", dpi=PRINT_QUALITY, bbox_inches='tight')

# %%
# CHAPTER 6 EVAL 6

plt.figure(figsize=(5.16, 2.4), dpi=150)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-BRAW.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-BRAW-GATED.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-BGATE.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-BGATE-GATED.xlsx'])

plt.subplot(1,2,1)
cor, nei, rel, par, wei = a
plt.title("pop", y=1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), ('simple', 'gated','simple', 'gated'))
plt.text(0.2,-0.2,  r'\textsc{braw}', fontsize=10)
plt.text(1.95,-0.2,  r'\textsc{bgate}', fontsize=10)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.text(-0.4, 1.40,  '0.78', fontsize=10)    
plt.text(0.16, 1.40,  'weighted', fontsize=8)
plt.legend(fontsize=8, frameon=False, loc=(0.45, 1.35), ncol=4)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-BRAW.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-BRAW-GATED.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-BGATE.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-BGATE-GATED.xlsx'])

cor, nei, rel, par, wei = a

plt.subplot(1,2,2)
plt.title(r"\textsc{edm} (\textsc{kfd} + \textsc{gs}\textsuperscript{+})", y=1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), ('simple', 'gated','simple', 'gated'))
plt.text(0.2,-0.2,  r'\textsc{braw}', fontsize=10)
plt.text(1.95,-0.2,  r'\textsc{bgate}', fontsize=10)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .0))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/comparison_2b.pdf', format="pdf", dpi=PRINT_QUALITY, bbox_inches='tight')

# %%
# CHAPTER 6 EVAL 7

plt.figure(figsize=(5.16, 2.4), dpi=150)

a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-BGATE.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-MULTI3.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-MULTI4.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-POP-MULTIX.xlsx'])

plt.subplot(1,2,1)
cor, nei, rel, par, wei = a
plt.title("pop", y=1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), (r'\textsc{bgate}', 'majmin','other', 'nokey'))
plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.text(-0.4, 1.40,  '0.82', fontsize=10)    
plt.text(0.16, 1.40,  'weighted', fontsize=8)
plt.legend(fontsize=8, frameon=False, loc=(0.45, 1.35), ncol=4)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-BGATE.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-MULTI3.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-MULTI4.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/AES-EDM-MULTIX.xlsx'])

cor, nei, rel, par, wei = a

plt.subplot(1,2,2)
plt.title(r"\textsc{edm} (\textsc{kfd} + \textsc{gs}\textsuperscript{+})", y=1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), (r'\textsc{bgate}', 'majmin','other', 'nokey'))
plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .0))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/comparison_3b.pdf', format="pdf", dpi=PRINT_QUALITY, bbox_inches='tight')

# %%
# CHAPTER 3 - PRELIMINARY EVAL

plt.figure(figsize=(5.16, 3.8), dpi=150)


a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-WTC-all-ambiguous.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-WTC-all-ambiguous.xlsx'])
cor, nei, rel, par, wei = a

plt.subplot(2,2,1)
plt.title(r'\textsc{wtc}', y=1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), (r'\textsc{es}', r'\textsc{qm}', r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=0)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)

plt.text(-0.5, 1.39,  '0.90', fontsize=10)    
plt.text(0.16, 1.42,  'weighted', fontsize=8)
plt.legend(fontsize=8, frameon=False, loc=(0.45, 1.35), ncol=4)

plt.subplot(2,2,2)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/PRE-ES-POP-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/PRE-QM-POP-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/PRE-KFA-POP-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/PRE-MIK-POP-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/PRE-TK-POP-majmin-single.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"pop (\textsc{bb} + \textsc{btl} + \textsc{rs})", y=1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), (r'\textsc{es}', r'\textsc{qm}', r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=0)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)
        
plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/preliminary_comparison.png', format="png", dpi=PRINT_QUALITY, bbox_inches='tight', transparent=True)

# %%
# chap 4 edm 

plt.figure(figsize=(2.58, 2.3), dpi=150)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/PRE-ES-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/PRE-QM-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/PRE-KFA-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/PRE-MIK-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/PRE-TK-EDM-majmin-single.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"\textsc{edm} (\textsc{kfd} + \textsc{gs\textsuperscript{k}})", y=1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), (r'\textsc{es}', r'\textsc{qm}',r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=0)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.21, 1.05, '%.2f' % wei[i], fontsize=10)
    
plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/preliminary_comparison_edm.png', format="png", dpi=PRINT_QUALITY, bbox_inches='tight', transparent=True)

# %%
# CHAPTER 6 - FINAL

plt.figure(figsize=(5.16, 7.2), dpi=150)


a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-WTC-all-ambiguous.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-WTC-all-ambiguous.xlsx'])
cor, nei, rel, par, wei = a

plt.subplot(3,2,1)
plt.title("euroclassical", y=1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)

plt.text(-0.45, 1.39,  '0.90', fontsize=8)    
plt.text(0.23, 1.39,  'weighted', fontsize=8)
plt.legend(fontsize=8, frameon=False, loc=(0.45, 1.35), ncol=4)

plt.subplot(3,2,2)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-POP-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-POP-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-POP-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-POP-all-ambiguous.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-POP-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-POP-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-POP-all-ambiguous.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"pop", y=1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)
    
plt.subplot(3,2,3)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-EDM-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-EDM-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-EDM-all-ambiguous.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-EDM-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-EDM-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-EDM-all-ambiguous.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"\textsc{edm}, all-ambiguous (\textsc{aa})", y=1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)
    
plt.subplot(3,2,4)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-EDM-all-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-all-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-EDM-all-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-EDM-all-single.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-EDM-all-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-EDM-all-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-EDM-all-single.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"\textsc{edm}, all-single (\textsc{as})", y=1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)
    
plt.subplot(3,2,5)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-EDM-majmin-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-majmin-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-EDM-majmin-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-EDM-majmin-ambiguous.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-EDM-majmin-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-EDM-majmin-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-EDM-majmin-ambiguous.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"\textsc{edm}, binary-ambiguous (\textsc{ba})", y=1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)
    
plt.subplot(3,2,6)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-EDM-majmin-single.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-EDM-majmin-single.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"\textsc{edm}, binary-single (\textsc{bs})", y=1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)
    
plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/comparison_final.png', format="png", dpi=PRINT_QUALITY, transparent=True)

# %%
# CHAPTER 6 - FINAL

plt.figure(figsize=(5.16, 7.2), dpi=150)


a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-WTC-all-ambiguous.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-WTC-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-WTC-all-ambiguous.xlsx'])
cor, nei, rel, par, wei = a

plt.subplot(3,2,1)
plt.title("euroclassical", y=1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)

plt.text(-0.45, 1.39,  '0.90', fontsize=8)    
plt.text(0.23, 1.39,  'weighted', fontsize=8)
plt.legend(fontsize=8, frameon=False, loc=(0.45, 1.35), ncol=4)

plt.subplot(3,2,2)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-POP-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-POP-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-POP-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-POP-all-ambiguous.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-POP-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-POP-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-POP-all-ambiguous.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"pop", y=1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)
    
plt.subplot(3,2,3)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-EDM-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-EDM-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-EDM-all-ambiguous.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-EDM-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-EDM-all-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-EDM-all-ambiguous.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"\textsc{edm}, all-ambiguous (\textsc{aa})", y=1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)
    
plt.subplot(3,2,4)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-EDM-all-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-all-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-EDM-all-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-EDM-all-single.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-EDM-all-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-EDM-all-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-EDM-all-single.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"\textsc{edm}, all-single (\textsc{as})", y=1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)
    
plt.subplot(3,2,5)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-EDM-majmin-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-majmin-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-EDM-majmin-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-EDM-majmin-ambiguous.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-EDM-majmin-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-EDM-majmin-ambiguous.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-EDM-majmin-ambiguous.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"\textsc{edm}, binary-ambiguous (\textsc{ba})", y=1.15)
plt.ylim([0,1])
plt.ylabel('accumulated percentages')
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)
    
plt.subplot(3,2,6)
a = get_scores_from_xlsx(['/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE2-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-BGATE+-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-ES-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-QM-EDM-majmin-single.xlsx', 
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-KFA-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-MIK-EDM-majmin-single.xlsx',
                          '/Users/angel/Dropbox/Apps/Texpad/Thesis/evaluation/THESIS/FINAL-TK-EDM-majmin-single.xlsx'])

cor, nei, rel, par, wei = a
plt.title(r"\textsc{edm}, binary-single (\textsc{bs})", y=1.15)
plt.ylim([0,1])
plt.xticks(range(len(a[0])), (r'\textsc{bgate}\textsuperscript{2}', r'\textsc{bgate}\textsuperscript{+}', r'\textsc{es}', r'\textsc{qm}', 
                              r'\textsc{kfa}',r'\textsc{mik}',r'\textsc{tk}'), rotation=45)

plt.bar(range(len(a[0])), cor, label='correct', linewidth=.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), nei, bottom=cor, label='neighbour', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), rel, bottom=np.add(cor,nei), label='relative', linewidth=0.0, edgecolor=(0, .0, .1))
plt.bar(range(len(a[0])), par, bottom=np.add(np.add(cor,nei),rel), label='parallel', linewidth=0.0, edgecolor=(0, .0, .1))
for i in range(len(wei)):
    plt.text(i-0.32, 1.05, '%.2f' % wei[i], fontsize=8)
    
plt.tight_layout()
plt.savefig('/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/comparison_final.png', format="png", dpi=PRINT_QUALITY, transparent=True)
