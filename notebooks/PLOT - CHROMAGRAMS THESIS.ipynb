# %%
# %matplotlib inline
from miran import *
import librosa
import librosa.display as ld
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns

sns.set_style('ticks', {'axes.linewidth': 0.2,  'axes.edgecolor': 'black',})
sns.set_palette("Reds_r"); my_palette='Reds'; libcolor='Reds'
mpl.rc('font', **{'family':'serif', 'serif':['Times']})
mpl.rc('xtick', labelsize=8)
mpl.rc('ytick', labelsize=8)
mpl.rc('axes', labelsize=9)
mpl.rc('text', usetex=True)
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.major.width'] = 0.3
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.major.width'] = 0.3

# %%
# HPCP!

plt.figure(figsize=(5.16, 2), dpi=150)
ld.specshow(csv_to_numpy('/Users/angel/Dropbox/Apps/Texpad/Thesis/audio/gs4/hpcp.csv').T, x_axis='time', sr=44100, hop_length=2049, cmap=libcolor)
plt.xlabel('time (secs.)')
plt.ylabel('chroma')
plt.yticks((0.5, 2.5, 4.5, 5.5, 7.5, 9.5, 11.5), ('c', 'd', 'e', 'f', 'g', 'a', 'b'))
plt.tight_layout()
#plt.savefig(os.path.join("/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/hpcp.pdf"), format="pdf", dpi=1200)
plt.show()

# %%
# NNLS
plt.figure(figsize=(5.16, 2), dpi=150)
ld.specshow(csv_to_numpy('/Users/angel/Dropbox/Apps/Texpad/Thesis/audio/gs4/nnls.csv').T, x_axis='time', sr=44100, hop_length=2048, cmap=libcolor)
plt.xlabel('time (secs.)')
plt.ylabel('chroma')
plt.yticks((0.5, 2.5, 4.5, 5.5, 7.5, 9.5, 11.5), ('c', 'd', 'e', 'f', 'g', 'a', 'b'))
plt.tight_layout()
#plt.savefig(os.path.join("/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/nnls.pdf"), format="pdf", dpi=1200)
plt.show()

# %%
# SPECTRAL WHITENING
plt.figure(figsize=(5.16, 3), dpi=150)

plt.subplot(2,2,1)
ld.specshow(np.array(nosw).T, x_axis='time', sr=44100, hop_length=16384, cmap=libcolor)
plt.xlabel('')
plt.xticks([])
plt.ylabel('chroma')

plt.subplot(2,2,2)
ld.specshow(np.array(spec).T, x_axis='time', sr=44100, hop_length=16384, cmap=libcolor)
plt.xlabel('')
plt.xticks([])
#plt.ylabel('chroma')

plt.subplot(2,2,3)
ld.specshow(np.array(nosw2).T, x_axis='time', sr=44100, hop_length=16384, cmap=libcolor)
plt.xlabel('time (secs.)')
plt.ylabel('chroma')

plt.subplot(2,2,4)
ld.specshow(np.array(spec2).T, x_axis='time', sr=44100, hop_length=16384, cmap=libcolor)
plt.xlabel('time (secs.)')
#plt.ylabel('chroma')

plt.tight_layout()
plt.savefig(os.path.join("/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/sw.pdf"), format="pdf", dpi=1200)
plt.show()

# %%
spec1= [[ 0.46022597,  0.41334823,  0.40207547,  0.38010055,  0.63111317,
         6.24921964e-03,   4.87724133e-03,   6.28639758e-02,
         8.88155624e-02,   2.63553895e-02,   1.06029247e-03,
         9.92406509e-04,   1.08058390e-03,   1.52358515e-02,
         2.56449357e-02,   1.16242897e-02,   4.31747101e-02,
         6.65359646e-02,   1.66882083e-01,   1.00000000e+00,
         8.57538640e-01,   9.47371242e-04,   1.81068759e-03,
         2.33812444e-03,   6.66345761e-04,   4.00406774e-04,
         6.10905839e-03,   5.75482845e-03,   1.58170436e-03]]

# %%
# NNLS
plt.figure(figsize=(5.16, 2), dpi=150)
ld.specshow(csv_to_numpy2('/Users/angel/Insync/Datasets/giantsteps/splits/nnls/101069 The Knife - Silent Shout (Williams Acidic Circutis Remix) - 4.nnls').T, x_axis='time', sr=44100, hop_length=2048, cmap=libcolor)
plt.xlabel('time (secs.)')
plt.ylabel('chroma')
plt.yticks((0.5, 2.5, 4.5, 5.5, 7.5, 9.5, 11.5), ('c', 'd', 'e', 'f', 'g', 'a', 'b'))
plt.tight_layout()
plt.savefig(os.path.join("/Users/angel/Dropbox/Apps/Texpad/Thesis/figures/THES.pdf"), format="pdf", dpi=1200)
plt.show()


#plot_chroma(csv_to_numpy2('/Users/angel/Insync/Datasets/giantsteps/splits/nnls/101069 The Knife - Silent Shout (Williams Acidic Circutis Remix) - 10.nnls').T)

# %%
def plot_chroma(chromagram, name="untitled", sr=44100, hl=2048,
                output_dir="/Users/angel/Dropbox/Apps/Texpad/Thesis/figures", cmap='magma'):

    from librosa.display import specshow
    with sns.axes_style('ticks'):
        if chromagram.shape[0] == 12:
            plt.figure(figsize=(5.16, 2), dpi=150)
            plt.yticks((0.5, 2.5, 4.5, 5.5, 7.5, 9.5, 11.5), ('c', 'd', 'e', 'f', 'g', 'a', 'b'))

        elif chromagram.shape[0] == 36:
            plt.figure(figsize=(5.16, 2.5), dpi=150)
            plt.yticks((0.5, 3.5, 6.5, 9.5, 12.5, 15.5, 18.5, 21.5, 24.5, 27.5, 30.5, 33.5),
                       ('c', r'c$\sharp$', 'd', r'e$\flat$', 'e', 'f', r'f$\sharp$', 'g', r'a$\flat$', 'a', r'b$\flat$', 'b'))

        specshow(chromagram, x_axis='time', sr=sr, hop_length=hl, cmap=cmap)
        plt.xlabel('time (secs.)')
        plt.ylabel('chroma')
        plt.yticks((0.5, 2.5, 4.5, 5.5, 7.5, 9.5, 11.5), ('c', 'd', 'e', 'f', 'g', 'a', 'b'))
        plt.tight_layout()
        plt.savefig(os.path.join(output_dir, name + '.pdf'), format="pdf", dpi=1200)
        plt.show()

# %%
a= csv_to_numpy('/Users/angel/Dropbox/Apps/Texpad/Thesis/audio/gs4/nnls.csv')
b=csv_to_numpy('/Users/angel/Insync/Datasets/giantsteps/splits/nnls/101069 The Knife - Silent Shout (Williams Acidic Circutis Remix) - 3.nnls')

# %%
a.shape
# Out:
# (652, 12)

# %%
b.shape
# Out:
# (156, 13)
