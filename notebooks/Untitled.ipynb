# %%
from miran import *

# %%
files = folderfiles('/Users/angel/Desktop/WTC', recursive=True, ext=('.txt', '.flac', '.mp3'))

# %%
len(files)
# Out:
# 672

# %%
for item in files:
    root, name = os.path.split(item)
    name, ext = os.path.splitext(name)
    name = name.split(' - ')
    name = '{} - {}{}'.format(name[1], name[0], ext)
    name = os.path.join(root, name)
    print(name)
    os.rename(item, name)
# Out:
# /Users/angel/Desktop/WTC/more/30s/Prelude in Bbm - BWV 891a.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in F# - BWV 858b.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in  Fm - BWV 881b.flac
# /Users/angel/Desktop/WTC/more/30s/Prelude in C#m - BWV 873a.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in C - BWV 870b.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in B - BWV 868a.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in E - BWV 878b.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in G#m - BWV 863b.flac
# /Users/angel/Desktop/WTC/more/30s/Prelude in E - BWV 878a.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in Ab - BWV 862b.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in F#m - BWV 859b.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in G#m - BWV 887b.flac
# /Users/angel/Desktop/WTC/more/30s/Prelude in F#m - BWV 859a.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in C# - BWV 848b.flac
# /Users/angel/Desktop/WTC/more/30s/Fugue in Em - BWV 855b.flac
# ...
