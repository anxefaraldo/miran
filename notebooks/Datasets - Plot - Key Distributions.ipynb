# %%
# %matplotlib inline
from matplotlib import gridspec

import re
import math
import os.path
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from miran import *

sns.set_style('whitegrid', {'axes.linewidth': 0.2,  'axes.edgecolor': 'gray', 'axes.facecolor':'snow'})
sns.set_palette("Reds_d", 2); my_palette='Reds'; libcolor='Reds'
mpl.rc('font', **{'family':'serif', 'serif':['Times']})
mpl.rc('xtick', labelsize=8)
mpl.rc('ytick', labelsize=8)
mpl.rc('axes', labelsize=9)
mpl.rc('text', usetex=True)

# PRINT IN GREYSCALE
#sns.set_palette("Greys_r"); my_palette='Greys'; libcolor='gray_r'
# PRINT IN COLOR
sns.set_palette("Reds_d", 2); my_palette='Reds'; libcolor='Reds'

# %%
plot_majmin_dist('/Users/angel/Insync/datasets/billboard/keys', name='Billboard', ext='.key', nokey=False)

# %%
plot_majmin_dist('/Users/angel/Insync/datasets/beatles/keys-pollack/', name='The Beatles', ext='.key', nokey=False)

# %%
plot_majmin_dist('/Users/angel/Insync/datasets/RS200/keys', name='RS200', ext='.key', nokey=False)

# %%
plot_majmin_dist('/Users/angel/Insync/Datasets/_POP', name='Popular Music (combined)', ext='.key', nokey=False)

# %%
plot_majmin_dist('/Users/angel/Insync/datasets/keyFinder/keys', name='KeyFinder', ext='.txt', nokey=False)

# %%
plot_majmin_dist('/Users/angel/Insync/datasets/giantsteps/keys_v1/', name='GiantSteps', ext='.key', nokey=False)

# %%
plot_majmin_dist('/Users/angel/Insync/Datasets/_EDM', name='EDM (combined)', ext='.txt', nokey=False)

# %%
plot_majmin_dist('/Users/angel/Insync/datasets/classicalDB/keys', name='Classical DB', ext='.txt', nokey=False)
